# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import json
import sys
sys.path.append('../')

from ProjectUtils import utils


_FOLDER = "../data/"

# %%
print(utils.TrainTestSplit(_FOLDER+'filteredResponsesWithCCL.csv', 'done.json'))
print(utils.TrainTestSplit(_FOLDER+'filteredResponsesWithCCLAndParams.csv', 'done.json'))
# Out:
# DONE
# DONE

# %%
filterPlateau = pd.read_csv(_FOLDER+'filteredResponsesWithCCLAndParams.csv')
filterPlateau
# Out:
#      CELL_LINE_NAME  COSMIC_ID  DRUG_ID DRUGID_COSMICID  MAX_CONC  fd_num_0  \
# 0            HDQ-P1    1290922      344     344_1290922     20.00         0
# 1            HDQ-P1    1290922      136     136_1290922     16.00         0
# 2            HDQ-P1    1290922      170     170_1290922     16.00         0
# 3            NMC-G1     908449      170      170_908449     16.00         0
# 4            NMC-G1     908449      331      331_908449     10.24         0
# ...             ...        ...      ...             ...       ...       ...
# 5579         TC-YIK     946357     1011     1011_946357      2.00         0
# 5580          MKN45     925340     1149     1149_925340      5.00         0
# 5581       EC-GI-10     753555     1004     1004_753555      0.10         0
# 5582        IGROV-1     905968     1031     1031_905968      0.20         0
# 5583       SKG-IIIa     930298     1012     1012_930298     10.00         0
#
#       fd_num_1  fd_num_2  fd_num_3  fd_num_4  ...  \
# ...

# %%
drugIDs = list(filterPlateau['DRUG_ID'].unique())
drugIDs = np.squeeze(drugIDs)

# %%
trainTest = {}
lowest = 1000
lowestId = 0
for drugID in drugIDs:
    drugResponses = list(filterPlateau.loc[filterPlateau['DRUG_ID'] == drugID]['DRUGID_COSMICID'])
    if(len(drugResponses) < lowest):
        lowest = len(drugResponses)
        lowestId = drugID
    data = []
    trainDCID, testDCID = train_test_split(drugResponses, test_size=0.2, random_state=42)
    data.append(trainDCID)
    data.append(testDCID)
    trainTest[str(drugID)] = data

# %%
with open(_FOLDER + 'dataSplit.json', 'w') as convert_file:
     convert_file.write(json.dumps(trainTest))
